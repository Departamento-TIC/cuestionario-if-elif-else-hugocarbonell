# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/cuestionario-if-elif-else-hugocarbonell/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
print('A jugar!')

contador = 0

pregunta1 = int(input('¿Cuántos equipos hay en la NBA?  '))
if pregunta1 == 30:
  print('Bien! Eres un fan de los deportes')
  contador += 1
else:
  print('Error! Sigue intentando')
print('Siguiente pregunta!')

pregunta2 = int(input('¿Cuánto es 5 * 2 + 3 ** 2?  '))
if pregunta2 == 19:
  print('Correcto!')
  contador += 1
else:
  print('No')
print('Siguiente pregunta!')

pregunta3 = int(input('¿Cuánto es 5 * 3 + 8?  '))
if pregunta3 == 23:
  print('Eso es!')
  contador += 1
else:
  print('Error!')
print('Siguiente pregunta!')

pregunta4 = print('¿Cuál es la selección con más mundiales?')
print('1. Alemania')
print('2. Brasil')
print('3. Argentina')
print('4. Italia')
equipo = int(input('?'))
if equipo == 2:
  print('Genial!')
  contador += 1
elif equipo == Brasil:
  print('Genial!')
  contador += 1
else:
  print('Casi, la respuesta era Brasil')
print('Última pregunta')
pregunta5 = print('¿En qué año se descubrió Ámerica?')
print('1. 476')
print('2. 1789')
print('3. 1492')
print('4. 1914')
fecha = int(input('?'))
if fecha == 3:
  print('Perfecto, cuestionario terminado!')
  contador += 1
elif fecha == 1492:
  print('Perfecto, cuestionario terminado!')
  contador += 1
else:
  print('No!, la respuesta correcta es 1492')
print('Enhorabuena! Has obtenido ',contador,'respuestas correctas. Eso es un total del',(contador/5)*100,'%!')
print('Mis felicitaciones!')
# Out:
# A jugar!
# ¿Cuántos equipos hay en la NBA?  30
# Bien! Eres un fan de los deportes
# Siguiente pregunta!
# ¿Cuánto es 5 * 2 + 3 ** 2?  19
# Correcto!
# Siguiente pregunta!
# ¿Cuánto es 5 * 3 + 8?  23
# Eso es!
# Siguiente pregunta!
# ¿Cuál es la selección con más mundiales?
# 1. Alemania
# 2. Brasil
# 3. Argentina
# 4. Italia
# ?2
# Genial!
# Última pregunta
# ¿En qué año se descubrió Ámerica?
# 1. 476
# 2. 1789
# 3. 1492
# 4. 1914
# ?3
# Perfecto, cuestionario terminado!
# Enhorabuena! Has obtenido  5 respuestas correctas. Eso es un total del 100.0 %!
# Mis felicitaciones!
